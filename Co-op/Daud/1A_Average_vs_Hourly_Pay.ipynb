# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/SYDE-26/1A-Class-Profile-Data-Analysis/main/Co-op/Daud/Data/1A_Avg_vs_Salary_Box_Plot.csv?token=GHSAT0AAAAAABSITQEIMRMTOA4RNZ4DGU56YRXKRQQ'
df = pandas.read_csv(url)

plt.rcParams['figure.figsize'] = (15,8)

df.boxplot(by ='1A Average', grid=False, column =['Pay $CAD/hr'], color='#4C7DFA')

plt.title('1A Average vs Hourly Pay [n=69]')
plt.suptitle('')
plt.xlabel('1A Average')
plt.ylabel('Hourly Pay ($CAD/hr)')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0, 0.5, 'Hourly Pay ($CAD/hr)')
