# %%
import matplotlib.pyplot as plt
import numpy as np

# Test data
subequalto80 = [16, 18.5, 18.5, 19, 22, 27, 28, 28]
from81to85 = [16.3, 16.67, 17.25, 18, 18.5, 18.75, 19, 19, 20, 20, 20, 20, 20, 21, 21, 22.5, 26]
from86to89 = [16.43, 17.5, 18.5, 18.5, 18.5, 18.5, 19, 19, 19.63, 20, 20, 20, 20.19, 20.5, 21, 22, 22, 23, 24, 26, 27, 27.5, 28, 28, 31.2]
overequal90 = [17, 18, 18, 19, 19, 19, 20.19, 20.19, 20.35, 20.75, 21, 22, 23, 23.25, 23.5, 24, 24.54, 26.67, 27]
all_data = [subequalto80, from81to85, from86to89, overequal90]
labels = ['<=80%', '81%-85%', '86%-89%', '>=90%']

fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(15, 8))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,
                     boxprops=dict(facecolor='#F7BF00', color='#F7BF00'),
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('1A Average vs Hourly Pay [n=69]')



# adding horizontal grid lines
for ax in [ax1]:
     ax.set_xlabel('Academic Average')
     ax.set_ylabel('Coop Pay ($CAD/hr)')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
