# %%
import numpy as np
import matplotlib.pyplot as plt

labels = ['1st Round', '2nd Round', 'Continuous', 'Direct Offer']
males = [23.02, 20.77, 19.93, 20.15]
females = [21.74,21.24,22.48,18]
nonb = [0,0,18.00,0]

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars



fig, ax = plt.subplots(figsize=(15, 8))
rects1 = ax.bar(x - width/2, males, width, label='Males', color = '#F7BF00')
rects2 = ax.bar(x + width/2, females, width, label='Females', color = '#FE8C5A')
rects3 = ax.bar(x + 0.3, nonb, width, label='Non-Binary', color = '#FBA62D')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Pay ($CAD/hr)')
ax.set_xlabel('Round Hired')
ax.set_title('Gender vs Pay vs Round [n=86]')
ax.set_xticks(x, labels)
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)


fig.tight_layout()

plt.show()
