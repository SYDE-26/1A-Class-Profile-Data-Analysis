# %%
# Job Type vs Pay
import matplotlib.pyplot as plt
import numpy as np

# Random test data
data = [18, 19, 20.19,17]
pm = [16.3, 16.5, 18.5, 19, 20, 21, 23, 25]
pd = [19, 20, 22, 27]
uxui = [18.5,19,19, 20.19, 22, 23,28,28,16.43]
software = [16, 16.67, 16.67, 17.25, 17.25, 17.5, 18, 18, 18, 18, 18.5, 18.5, 18.5, 18.5, 18.75, 19, 19, 19, 19, 19.63, 20, 20, 20, 20, 20, 20, 20.19, 20.35, 20.5,
        20.75,21,18.5,20,21,21,22,22,22,22,22.5,23,23,23,23.25,23.5,24,24,24,24.54,25,26,26,26.67,27,27,27.5,28,28.25,31.2]
other = [21,28]
all_data = [software,pm,pd, uxui, data, other]
labels = ['Software', 'Product/Project \n Management', 'Product Design', 'UX/UI', 'Data Science & ML', 'Information Security']

fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(12, 4))

# rectangular box plot
bplot1 = ax1.boxplot(all_data,
                     vert=True,  # vertical box alignment
                     patch_artist=True,
                     boxprops=dict(facecolor='#4C7DFA', color='#4C7DFA'),
                     flierprops = dict(marker='o', markerfacecolor='#4C7DFA', markersize=7,
                  linestyle='none'),
                     labels=labels)  # will be used to label x-ticks
ax1.set_title('Type of Coop vs Hourly Coop Pay [85 Respondents]')


# adding horizontal grid lines
for ax in [ax1]:
    #ax.yaxis.grid(True)
    ax.set_xlabel('Type of Coop')
    ax.set_ylabel('Hourly Coop Pay (CAD/hr)')

plt.show()
ax1.figure.savefig('TypeofCoopvsHourlyPay.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
