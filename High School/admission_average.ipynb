# %%
# Import dependecies 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data

data = pd.read_csv('data.csv')

# Identify column of interest and rename it

column = ['Admission Average']
relevant_data = data[column].dropna().rename(columns={'Admission Average': 'average'})

# %%
# Generate distribution

filtered_grades = relevant_data.dropna().sort_values(by='average')
print(filtered_grades)
# Out:
#     average
# 1      89.0
# 2      91.0
# 3      92.0
# 4      92.0
# 5      92.0
# ..      ...
# 84     98.6
# 85     99.0
# 86     99.0
# 87     99.2
# 88     99.8
#
# [88 rows x 1 columns]

# %%
# Plot graph with appropriate title, color palette, and data

plt.figure()
plt.title("Admission Average [Top 6, Including Prerequisites]")
ax = sns.histplot(x=filtered_grades["average"], data=filtered_grades, kde=True)
plt.xlabel("Average")
plt.ylabel("Number of Respondents")
# Out:
# Text(0, 0.5, 'Number of Respondents')

# %%
ax.figure.savefig('admission_average.svg')
