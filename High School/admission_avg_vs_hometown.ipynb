# %%
# Import dependecies 

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import data

data = pd.read_csv('data.csv')

# Identify columns of interest and rename them

column = ['avg', 'home']
relevant_data = data[column].rename(columns={'avg' : 'averages', 'home': 'hometowns'})

# %%
# Plot graph with appropriate title, color palette, and data

sns.set(rc={'figure.figsize': (23,10)})
graph = sns.boxplot(
    data=relevant_data, x="hometowns", y="averages", color ="#FE8C5A" 
)
graph.set_title('Admission Averages vs. Hometowns [n=91]')
graph.set_xlabel('Hometown')
graph.set_ylabel('Top 6 Admission Average [including prerequisites]')
# Out:
# Text(0, 0.5, 'Top 6 Admission Average [including prerequisites]')
