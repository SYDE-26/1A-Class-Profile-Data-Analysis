# %%
import matplotlib.pyplot as plt
   
Assignment = ['101L Vehicle','101L Name Tag','121 Game','101L Puzzle']
Responses = [38,11,8,6]

plt.bar(Assignment, Responses, width = 0.5)
plt.title('Favourite Assignment in 1A?')
plt.xlabel('Assignment')
plt.ylabel('Responses')


plt.show()
