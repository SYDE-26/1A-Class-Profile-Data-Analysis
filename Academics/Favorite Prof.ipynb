# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from os import path

# %%
prof_data = pd.read_csv("unordered.csv")
rel_cols = ['Favourite Professor?']
df = prof_data[rel_cols].dropna().rename(columns={'Favourite Professor?': 'prof'})
df
# Out:
#                    prof
# 0          Nasim Paryab
# 1         Sean Speziale
# 2          Nasim Paryab
# 3   Christopher Nehaniv
# 4          Jason Foster
# ..                  ...
# 87         Nasim Paryab
# 88        Sean Speziale
# 89       Ewen MacDonald
# 90        Sean Speziale
# 91  Christopher Nehaniv
#
# [89 rows x 1 columns]

# %%
grouped = df.groupby('prof')['prof'].count()
grouped
# Out:
# prof
# Christopher Nehaniv     5
# Ewen MacDonald         10
# Jason Foster           17
# MattBorland             1
# Nasim Paryab           27
# Sean Speziale          29
# Name: prof, dtype: int64

# %%
text = " ".join(prof for prof in df.prof)

# %%
ax = wordcloud = WordCloud(background_color="white",max_font_size=45, max_words= len(text),relative_scaling=.6,colormap='Reds_r').generate(text)
plt.figure()
plt.imshow(wordcloud,interpolation='bilinear')
plt.tight_layout(pad=0)
plt.axis("off")
plt.show()

# %%
ax.to_file('graphs/FAV_prof.png')
