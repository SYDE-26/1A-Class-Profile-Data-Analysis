# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from subprocess import check_output
from wordcloud import WordCloud, STOPWORDS
import string
import re 
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer 
from nltk.tokenize import word_tokenize
from nltk.tokenize import TweetTokenizer

# %%
prof_data = pd.read_csv("unordered.csv")
rel_cols = ['Favourite Professor?']
df = prof_data[rel_cols].dropna().rename(columns={'Favourite Professor?': 'prof'})
df
# Out:
#                    prof
# 0          Nasim Paryab
# 1         Sean Speziale
# 2          Nasim Paryab
# 3   Christopher Nehaniv
# 4          Jason Foster
# ..                  ...
# 87         Nasim Paryab
# 88        Sean Speziale
# 89       Ewen MacDonald
# 90        Sean Speziale
# 91  Christopher Nehaniv
#
# [89 rows x 1 columns]

# %%
grouped = df.groupby('prof')['prof'].count()
grouped
# Out:
# prof
# Christopher Nehaniv     5
# Ewen MacDonald         10
# Jason Foster           17
# Matt Borland            1
# Nasim Paryab           26
# Sean Speziale          30
# Name: prof, dtype: int64

# %%
text = " ".join(prof for prof in df.prof)

# %%
ax = wordcloud = WordCloud(background_color="white",max_font_size=40, relative_scaling=.5).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
ax.figure.figure.savefig('graphs/Fav_prof.svg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-91-32bb326e77c2> in <module>
# ----> 1 ax.figure.figure.savefig('graphs/Fav_prof.svg')
#
# AttributeError: 'WordCloud' object has no attribute 'figure'
