# %%
import matplotlib.pyplot as plt
   
Assignment = ['Create a Vehicle Using OnShape (101L)','Create a 3D-Printed Name Tag (101L)','Create a Computer Game (121)','Creating a 3D-Printed Puzzle (101L)']
Responses = [38,11,8,6]
ResponsesLabels = ['60%','17%','13%','10%']

fig, ax = plt.subplots(figsize=(14,8))
rect = plt.bar(Assignment, Responses, width = 0.5,color='#FF76A5')
plt.title('Favourite Assignment in 1A? [n=63]')
plt.xlabel('Assignment')
plt.ylabel('Number of Responses')
ax.bar_label(rect, labels=ResponsesLabels, padding = 3)

plt.show()
